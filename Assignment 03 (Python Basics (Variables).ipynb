# %% [markdown]
# ## Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
print("Name:\tcyril Samuel")
print("Father Name:\tSamuel ")
print("Date of Birth:\t22-08-2011")
# Out:
# Name:	cyril Samuel
# Father Name:	Samuel
# Date of Birth:	22-08-2011

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
name = "cyril Samuel"
father_name = "Samuel"
age = 15
course = "(python)"
city = "Karachi"

print("----- My Bio -----")
print("Name:", name)
print("Father Name:", father_name)
print("Age:", age)
print("Course:", course)
print("Semester:", semester)
print("City:", city)
# Out:
# ----- My Bio -----
# Name: cyril Samuel
# Father Name: Samuel
# Age: 15
# Course: (python)
# Semester: 4
# City: Karachi

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
a = 10
b = 5

print(a+b, a-b, a*b, a/b, a//b, a%b, a**b)

print(a==b, a!=b, a>b, a<b, a>=b, a<=b)

c = 10
c += 5
print(c)

print(a>b and b<a)
print(a<b or b<a)
print(not(a==b))

print(a&b, a|b, a^b, ~a, a<<1, a>>1)

L = [10, 20, 30]
print(10 in L, 40 not in L)

x = L
y = [10, 20, 30]
print(x is L, x is not y)
# Out:
# 15 5 50 2.0 2 0 100000
# False True True False True False
# 15
# True
# True
# True
# 0 15 15 -11 20 5
# True True
# True True

# %% [markdown]
# 4. Completes the following steps of small task:
# Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
# Mention Variable of Total Marks and assign 300 to it
# Calculate Percentage

# %%
english = 85
islamiat = 90
maths = 95

total_marks = 300

obtained_marks = english + islamiat + maths

percentage = (obtained_marks / total_marks) * 100

print("English Marks:", english)
print("Islamiat Marks:", islamiat)
print("Maths Marks:", maths)
print("Total Marks:", total_marks)
print("Obtained Marks:", obtained_marks)
print("Percentage:", percentage, "%")
# Out:
# English Marks: 85
# Islamiat Marks: 90
# Maths Marks: 95
# Total Marks: 300
# Obtained Marks: 270
# Percentage: 90.0 %
